# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 50)
pd.set_option('display.width', 1000)

# %%
df1=pd.read_csv('CSV 1.csv')

df1.head()
# Out:
#         id        city country          fullStreetAddress postalCode stateOrProvince unitNumber  bathrooms  bedrooms                                 listingDescription                                       listingTitle  latitude  longitude  listPrice  livingArea livingAreaUnit  yearBuilt   lotSize lotSizeUnit         propertySubType listingCategory  numParkingSpaces                   createdAt  geocodioAccuracyScore  photoscount    grade
# 0  2698139   St Peters      US     12 Legacy Estates Lane      63376              MO        NaN          6         5  Tucked away in the private Legacy Estates subd...           Residential, Traditional - St Peters, MO       NaN        NaN   425000.0      3046.0     squareFoot     1998.0       NaN  squareFoot  Single Family Detached        Purchase               3.0  2019-02-21 14:53:27.462+00                    NaN           29  awesome
# ...

# %% [markdown]
# Address and listing description is of no use in classification

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 26 columns):
# id                       900 non-null int64
# city                     900 non-null object
# country                  900 non-null object
# fullStreetAddress        900 non-null object
# postalCode               900 non-null object
# stateOrProvince          899 non-null object
# unitNumber               118 non-null object
# bathrooms                900 non-null int64
# bedrooms                 900 non-null int64
# listingDescription       842 non-null object
# listingTitle             900 non-null object
# latitude                 789 non-null float64
# longitude                789 non-null float64
# listPrice                900 non-null float64
# livingArea               726 non-null float64
# livingAreaUnit           900 non-null object
# yearBuilt                791 non-null float64
# lotSize                  562 non-null float64
# ...

# %%
df2=pd.read_csv('CSV 2.csv')

df2.head()
# Out:
#         id  favouritecount
# 0  2698139               0
# 1  2698093               0
# 2  2698007               0
# 3  2697963               0
# 4  2697938               0

# %%
df3=pd.read_csv('CSV 3.csv')

df3.head()
# Out:
#         id  collabprojectscount
# 0  2698139                    0
# 1  2698093                    0
# 2  2698007                    0
# 3  2697963                    0
# 4  2697938                    0

# %%
df=df1.merge(df2,how='left',on=['id'])#merging the data of csv2 wrt csv1

# %%
df=df.merge(df3,how='left',on=['id'])#merging the data of csv3 wrt csv1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 900 entries, 0 to 899
# Data columns (total 28 columns):
# id                       900 non-null int64
# city                     900 non-null object
# country                  900 non-null object
# fullStreetAddress        900 non-null object
# postalCode               900 non-null object
# stateOrProvince          899 non-null object
# unitNumber               118 non-null object
# bathrooms                900 non-null int64
# bedrooms                 900 non-null int64
# listingDescription       842 non-null object
# listingTitle             900 non-null object
# latitude                 789 non-null float64
# longitude                789 non-null float64
# listPrice                900 non-null float64
# livingArea               726 non-null float64
# livingAreaUnit           900 non-null object
# yearBuilt                791 non-null float64
# lotSize                  562 non-null float64
# ...

# %%
df.isna().sum()/len(df)
# Out:
# id                       0.000000
# city                     0.000000
# country                  0.000000
# fullStreetAddress        0.000000
# postalCode               0.000000
# stateOrProvince          0.001111
# unitNumber               0.868889
# bathrooms                0.000000
# bedrooms                 0.000000
# listingDescription       0.064444
# listingTitle             0.000000
# latitude                 0.123333
# longitude                0.123333
# listPrice                0.000000
# livingArea               0.193333
# livingAreaUnit           0.000000
# yearBuilt                0.121111
# lotSize                  0.375556
# lotSizeUnit              0.000000
# propertySubType          0.000000
# listingCategory          0.000000
# numParkingSpaces         0.488889
# createdAt                0.000000
# geocodioAccuracyScore    0.970000
# photoscount              0.000000
# grade                    0.000000
# favouritecount           0.000000
# ...

# %% [markdown]
# unitNumber and geocodioAccuracyScore are of no use as they have huge nulls

# %%
df.select_dtypes(exclude='object').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 900 entries, 0 to 899
# Data columns (total 14 columns):
# id                       900 non-null int64
# bathrooms                900 non-null int64
# bedrooms                 900 non-null int64
# latitude                 789 non-null float64
# longitude                789 non-null float64
# listPrice                900 non-null float64
# livingArea               726 non-null float64
# yearBuilt                791 non-null float64
# lotSize                  562 non-null float64
# numParkingSpaces         460 non-null float64
# geocodioAccuracyScore    27 non-null float64
# photoscount              900 non-null int64
# favouritecount           900 non-null int64
# collabprojectscount      900 non-null int64
# dtypes: float64(8), int64(6)
# memory usage: 105.5 KB

# %%
df.select_dtypes(include='object').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 900 entries, 0 to 899
# Data columns (total 14 columns):
# city                  900 non-null object
# country               900 non-null object
# fullStreetAddress     900 non-null object
# postalCode            900 non-null object
# stateOrProvince       899 non-null object
# unitNumber            118 non-null object
# listingDescription    842 non-null object
# listingTitle          900 non-null object
# livingAreaUnit        900 non-null object
# lotSizeUnit           900 non-null object
# propertySubType       900 non-null object
# listingCategory       900 non-null object
# createdAt             900 non-null object
# grade                 900 non-null object
# dtypes: object(14)
# memory usage: 105.5+ KB

# %% [markdown]
# ### inspecting object type data

# %%
df.country.value_counts()
# Out:
# US    897
# CA      2
# PR      1
# Name: country, dtype: int64

# %% [markdown]
# country is of no use because all of them except 3 are from same country so it nust not create any difference

# %%
df.city.value_counts()
# Out:
# Las Vegas                               31
# Miami                                   23
# Other City - In The State Of Florida    10
# Henderson                                9
# St Bernard                               8
# New York                                 8
# Brooklyn                                 7
# Pahrump                                  6
# JACKSONVILLE                             6
# Flint                                    6
# CHICAGO                                  6
# Aventura                                 5
# East Dublin                              5
# North Las Vegas                          5
# Miami Beach                              5
# ST PETERSBURG                            5
# Charlotte                                5
# Des Moines                               4
# Coral Springs                            4
# Henrico                                  4
# Basehor                                  4
# Canton                                   4
# ...

# %% [markdown]
# in 900 data rows having 620 city will also not hamper the data

# %%
df.stateOrProvince.value_counts()
# Out:
# FL    166
# NY     64
# NV     53
# TX     51
# GA     43
# NJ     36
# CA     34
# AZ     32
# MO     29
# NC     29
# IL     26
# TN     24
# VA     23
# MI     22
# IA     18
# SC     18
# AL     18
# WI     16
# AR     15
# KY     15
# OK     14
# LA     14
# PA     12
# OH     11
# KS     10
# IN     10
# NE      9
# ME      9
# WA      9
# MD      8
# OR      7
# NM      6
# ID      6
# MN      4
# MA      4
# CO      3
# WY      3
# UT      3
# WV      3
# MS      3
# RI      3
# DC      2
# NH      2
# CT      2
# VT      2
# PR      2
# ON      2
# DE      1
# SD      1
# HI      1
# MT      1
# Name: stateOrProvince, dtype: int64

# %%
df.lotSizeUnit.value_counts()
# Out:
# squareFoot    900
# Name: lotSizeUnit, dtype: int64

# %% [markdown]
# lotSizeUnit has same unit for all the rows so it will also not matter

# %%
df.listingTitle.value_counts()
# Out:
# Single Family Residential - Las Vegas, NV                                         17
# Residential Land/Boat Docks - Other City - In The State Of Florida, FL            10
# Residential Land/Boat Docks - Miami, FL                                            9
# Vacant Land - St Bernard, LA                                                       8
# Residential Rental, Single Family - Las Vegas, NV                                  6
# Single Family Residence - Flint, MI                                                6
# Single Family Residential - Henderson, NV                                          5
# Single Family Detached, Ranch - East Dublin, GA                                    5
# Single Family Residential - Pahrump, NV                                            5
# Residential Rental, Condo - Las Vegas, NV                                          5
# LSE-House - Lucas, TX                                                              4
# ...

# %% [markdown]
# in 900 data rows having 772 city will also not hamper the data

# %%
#Droping all the unnecessesory columns
df=df.drop(['fullStreetAddress','listingDescription','lotSizeUnit','unitNumber','geocodioAccuracyScore','listingTitle','city','country'],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 900 entries, 0 to 899
# Data columns (total 20 columns):
# id                     900 non-null int64
# postalCode             900 non-null object
# stateOrProvince        899 non-null object
# bathrooms              900 non-null int64
# bedrooms               900 non-null int64
# latitude               789 non-null float64
# longitude              789 non-null float64
# listPrice              900 non-null float64
# livingArea             726 non-null float64
# livingAreaUnit         900 non-null object
# yearBuilt              791 non-null float64
# lotSize                562 non-null float64
# propertySubType        900 non-null object
# listingCategory        900 non-null object
# numParkingSpaces       460 non-null float64
# createdAt              900 non-null object
# photoscount            900 non-null int64
# grade                  900 non-null object
# favouritecount         900 non-null int64
# ...

# %%
#manually check the data
df.head(10)
# Out:
#         id postalCode stateOrProvince  bathrooms  bedrooms  latitude  longitude  listPrice  livingArea livingAreaUnit  yearBuilt    lotSize         propertySubType listingCategory  numParkingSpaces                   createdAt  photoscount    grade  favouritecount  collabprojectscount
# 0  2698139      63376              MO          6         5       NaN        NaN   425000.0      3046.0     squareFoot     1998.0        NaN  Single Family Detached        Purchase               3.0  2019-02-21 14:53:27.462+00           29  awesome               0                    0
# 1  2698093      63119              MO          2         3       NaN        NaN   175000.0      1587.0     squareFoot     1962.0    7753.68  Single Family Detached        Purchase               1.0   2019-02-21 14:53:07.92+00           29  awesome               0                    0
# ...

# %%
df.postalCode.value_counts()
# Out:
# 70085         8
# 31027         5
# 89048         5
# 33185         5
# 66007         4
# 33180         4
# 75002         4
# 33139         4
# 41101         3
# 8527          3
# 83638         3
# 33322         3
# 33705         3
# 85615         3
# 33876         3
# 89122         3
# 68022         3
# 89074         3
# 33133         3
# 33157         3
# 11232         2
# 89120         2
# 65203         2
# 89147         2
# 24360         2
# 89131         2
# 32773         2
# 75078         2
# 33015         2
# 90049         2
# 89011         2
# 32259         2
# 33071         2
# 54403         2
# 85249         2
# 32826         2
# 33913         2
# 12946         2
# 11040         2
# 76034         2
# 33154         2
# 33178         2
# 33033         2
# 32208         2
# 27332         2
# 10128         2
# 30252         2
# 8755          2
# 7030          2
# 89148         2
# 33027         2
# 33777         2
# 11577         2
# 89081         2
# 34134         2
# ...

# %% [markdown]
# postal code is also of no use

# %%
df.livingAreaUnit.value_counts()
# Out:
# squareFoot    900
# Name: livingAreaUnit, dtype: int64

# %% [markdown]
# livingAreaUnit is same for all the rows so not important

# %%
df.propertySubType.value_counts()#important
# Out:
# Single Family Detached    636
# Condominium                81
# Other                      65
# Townhouse                  31
# Single Family Attached     23
# Apartment                  21
# Duplex                     20
# Mobile Home                 8
# Manufactured Home           4
# Timeshare                   3
# Stock Cooperative           2
# Triplex                     2
# Farm                        2
# Quadruplex                  2
# Name: propertySubType, dtype: int64

# %%
df.listingCategory.value_counts()#important
# Out:
# Purchase    778
# Rent        122
# Name: listingCategory, dtype: int64

# %%
df.grade.value_counts()#important
# Out:
# good       301
# awesome    300
# bad        299
# Name: grade, dtype: int64

# %%
#dropping the non important features
df=df.drop(['postalCode','livingAreaUnit','createdAt'],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 900 entries, 0 to 899
# Data columns (total 17 columns):
# id                     900 non-null int64
# stateOrProvince        899 non-null object
# bathrooms              900 non-null int64
# bedrooms               900 non-null int64
# latitude               789 non-null float64
# longitude              789 non-null float64
# listPrice              900 non-null float64
# livingArea             726 non-null float64
# yearBuilt              791 non-null float64
# lotSize                562 non-null float64
# propertySubType        900 non-null object
# listingCategory        900 non-null object
# numParkingSpaces       460 non-null float64
# photoscount            900 non-null int64
# grade                  900 non-null object
# favouritecount         900 non-null int64
# collabprojectscount    900 non-null int64
# dtypes: float64(7), int64(6), object(4)
# memory usage: 126.6+ KB

# %%
df.head(10)
# Out:
#         id stateOrProvince  bathrooms  bedrooms  latitude  longitude  listPrice  livingArea  yearBuilt    lotSize         propertySubType listingCategory  numParkingSpaces  photoscount    grade  favouritecount  collabprojectscount
# 0  2698139              MO          6         5       NaN        NaN   425000.0      3046.0     1998.0        NaN  Single Family Detached        Purchase               3.0           29  awesome               0                    0
# 1  2698093              MO          2         3       NaN        NaN   175000.0      1587.0     1962.0    7753.68  Single Family Detached        Purchase               1.0           29  awesome               0                    0
# 2  2698007              MO          3         3       NaN        NaN   295000.0      2437.0     1986.0   14766.84             Condominium        Purchase               2.0           29  awesome               0                    0
# ...

# %%
df.isna().sum()
# Out:
# id                       0
# stateOrProvince          1
# bathrooms                0
# bedrooms                 0
# latitude               111
# longitude              111
# listPrice                0
# livingArea             174
# yearBuilt              109
# lotSize                338
# propertySubType          0
# listingCategory          0
# numParkingSpaces       440
# photoscount              0
# grade                    0
# favouritecount           0
# collabprojectscount      0
# dtype: int64

# %%
df.numParkingSpaces
# Out:
# 0       3.0
# 1       1.0
# 2       2.0
# 3       2.0
# 4       3.0
# 5       2.0
# 6       2.0
# 7       1.0
# 8       2.0
# 9       2.0
# 10      0.0
# 11      3.0
# 12      0.0
# 13      0.0
# 14      0.0
# 15      1.0
# 16      0.0
# 17      1.0
# 18      2.0
# 19      1.0
# 20      0.0
# 21      0.0
# 22      0.0
# 23      1.0
# 24      1.0
# 25      4.0
# 26      2.0
# 27      1.0
# 28      1.0
# 29      1.0
# 30      2.0
# 31      2.0
# 32      0.0
# 33      1.0
# 34      2.0
# 35      0.0
# 36      2.0
# 37      2.0
# 38      0.0
# 39      2.0
# 40      1.0
# 41      1.0
# 42      1.0
# 43      NaN
# 44      NaN
# 45      NaN
# 46      NaN
# 47      NaN
# 48      NaN
# 49      NaN
# 50      NaN
# 51      NaN
# 52      NaN
# 53      NaN
# 54      NaN
# 55      NaN
# 56      NaN
# 57      NaN
# 58      NaN
# 59      NaN
# 60      NaN
# 61      NaN
# 62      NaN
# 63      NaN
# 64      NaN
# 65      NaN
# 66      NaN
# 67      NaN
# 68      NaN
# 69      NaN
# 70      NaN
# ...

# %% [markdown]
# in case of parking spaces we can assume that if not given means not present so we will fill it with 0

# %%
df['numParkingSpaces']=df['numParkingSpaces'].fillna(0)

# %% [markdown]
# yearBuilt we can fill it with the mod of all the years as it should be around it

# %%
df['yearBuilt']=df['yearBuilt'].fillna(df['yearBuilt'].mode())

# %% [markdown]
# lotside and living area can be considered as mean as it is the best option rather than excluding the rows

# %%
df['lotSize']=df['lotSize'].fillna(df['lotSize'].mean())
df['livingArea']=df['livingArea'].fillna(df['livingArea'].mean())

# %%
df.head()
# Out:
#         id stateOrProvince  bathrooms  bedrooms  listPrice  livingArea  yearBuilt        lotSize         propertySubType listingCategory  numParkingSpaces  photoscount    grade
# 0  2698139              MO          6         5   425000.0      3046.0     1998.0  122417.000783  Single Family Detached        Purchase               3.0           29  awesome
# 1  2698093              MO          2         3   175000.0      1587.0     1962.0    7753.680000  Single Family Detached        Purchase               1.0           29  awesome
# 2  2698007              MO          3         3   295000.0      2437.0     1986.0   14766.840000             Condominium        Purchase               2.0           29  awesome
# 3  2697963              MO          2         3   215000.0      1780.0     1969.0   11848.320000  Single Family Detached        Purchase               2.0           29  awesome
# ...

# %%
#we can drop this as stateorprovince will act as better one.
df=df.drop(['latitude','longitude'],axis=1)

# %%
print(df.collabprojectscount.value_counts())
print(df.favouritecount.value_counts())
# Out:
# 0    900
# Name: collabprojectscount, dtype: int64
# 0    900
# Name: favouritecount, dtype: int64

# %% [markdown]
# thus no point of keeping it

# %%
df=df.drop(['collabprojectscount','favouritecount'],axis=1)

# %%
df.head()
# Out:
#         id stateOrProvince  bathrooms  bedrooms  listPrice  livingArea  yearBuilt        lotSize         propertySubType listingCategory  numParkingSpaces  photoscount    grade
# 0  2698139              MO          6         5   425000.0      3046.0     1998.0  122417.000783  Single Family Detached        Purchase               3.0           29  awesome
# 1  2698093              MO          2         3   175000.0      1587.0     1962.0    7753.680000  Single Family Detached        Purchase               1.0           29  awesome
# 2  2698007              MO          3         3   295000.0      2437.0     1986.0   14766.840000             Condominium        Purchase               2.0           29  awesome
# 3  2697963              MO          2         3   215000.0      1780.0     1969.0   11848.320000  Single Family Detached        Purchase               2.0           29  awesome
# ...

# %%
df.corr().style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_2b702536_44e8_11e9_951a_efaf9f5e39b0row0_col0 {
#             background-color:  #023858;
#         }    #T_2b702536_44e8_11e9_951a_efaf9f5e39b0row0_col1 {
#             background-color:  #dcdaeb;
#         }    #T_2b702536_44e8_11e9_951a_efaf9f5e39b0row0_col2 {
#             background-color:  #e7e3f0;
#         }    #T_2b702536_44e8_11e9_951a_efaf9f5e39b0row0_col3 {
#             background-color:  #fef6fb;
#         }    #T_2b702536_44e8_11e9_951a_efaf9f5e39b0row0_col4 {
#             background-color:  #fff7fb;
#         }    #T_2b702536_44e8_11e9_951a_efaf9f5e39b0row0_col5 {
#             background-color:  #f4edf6;
#         }    #T_2b702536_44e8_11e9_951a_efaf9f5e39b0row0_col6 {
#             background-color:  #fdf5fa;
#         }    #T_2b702536_44e8_11e9_951a_efaf9f5e39b0row0_col7 {
#             background-color:  #fbf4f9;
#         }    #T_2b702536_44e8_11e9_951a_efaf9f5e39b0row0_col8 {
#             background-color:  #4a98c5;
# ...

# %%
df=df.dropna()

# %%
df.to_csv('cleaned_data.csv')
